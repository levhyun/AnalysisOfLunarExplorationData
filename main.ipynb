# %%
import pandas as pd

# %%
rock_samples = pd.read_csv('rocksamples.csv')
rock_samples
# Out:
#          ID   Mission     Type   Subtype  Weight (g)  Pristine (%)
# 0     10001  Apollo11     Soil  Unsieved      125.80         88.36
# 1     10002  Apollo11     Soil  Unsieved     5629.00         93.73
# 2     10003  Apollo11   Basalt  Ilmenite      213.00         65.56
# 3     10004  Apollo11     Core  Unsieved       44.80         71.76
# 4     10005  Apollo11     Core  Unsieved       53.40         40.31
# ...     ...       ...      ...       ...         ...           ...
# 2224  79528  Apollo17  Breccia  Regolith        2.38        100.00
# 2225  79529  Apollo17  Breccia  Regolith        1.84        100.00
# 2226  79535  Apollo17  Breccia  Regolith        1.69        100.00
# 2227  79536  Apollo17  Breccia  Regolith        1.66        100.00
# 2228  79537  Apollo17  Breccia  Regolith        1.05        100.00
#
# [2229 rows x 6 columns]

# %%
rock_samples.head()
# Out:
#       ID   Mission    Type   Subtype  Weight (g)  Pristine (%)
# 0  10001  Apollo11    Soil  Unsieved       125.8         88.36
# 1  10002  Apollo11    Soil  Unsieved      5629.0         93.73
# 2  10003  Apollo11  Basalt  Ilmenite       213.0         65.56
# 3  10004  Apollo11    Core  Unsieved        44.8         71.76
# 4  10005  Apollo11    Core  Unsieved        53.4         40.31

# %%
rock_samples.tail()
# Out:
#          ID   Mission     Type   Subtype  Weight (g)  Pristine (%)
# 2224  79528  Apollo17  Breccia  Regolith        2.38         100.0
# 2225  79529  Apollo17  Breccia  Regolith        1.84         100.0
# 2226  79535  Apollo17  Breccia  Regolith        1.69         100.0
# 2227  79536  Apollo17  Breccia  Regolith        1.66         100.0
# 2228  79537  Apollo17  Breccia  Regolith        1.05         100.0

# %%
rock_samples.shape[0]
# Out:
# 2229

# %%
rock_samples.index
# Out:
# RangeIndex(start=0, stop=2229, step=1)

# %%
rock_samples.columns
# Out:
# Index(['ID', 'Mission', 'Type', 'Subtype', 'Weight (g)', 'Pristine (%)'], dtype='object')

# %%
type(rock_samples)
# Out:
# pandas.core.frame.DataFrame

# %%
rock_samples.isnull().sum()
# Out:
# ID              0
# Mission         0
# Type            0
# Subtype         3
# Weight (g)      0
# Pristine (%)    0
# dtype: int64

# %%
rock_samples['Weight (g)'] = rock_samples['Weight (g)'].apply(lambda x : x * 0.001)
rock_samples.rename(columns={'Weight (g)': 'Weight (kg)'}, inplace=True)
rock_samples['Weight (kg)']
# Out:
# 0       0.12580
# 1       5.62900
# 2       0.21300
# 3       0.04480
# 4       0.05340
#          ...
# 2224    0.00238
# 2225    0.00184
# 2226    0.00169
# 2227    0.00166
# 2228    0.00105
# Name: Weight (kg), Length: 2229, dtype: float64

# %%
type(rock_samples['Weight (kg)'])
# Out:
# pandas.core.series.Series

# %%
missions = pd.DataFrame()
missions['Mission'] = rock_samples['Mission'].unique()
missions
# Out:
#     Mission
# 0  Apollo11
# 1  Apollo12
# 2  Apollo14
# 3  Apollo15
# 4  Apollo16
# 5  Apollo17

# %%
sample_total_weight = rock_samples.groupby('Mission')['Weight (kg)'].sum()
sample_total_weight
# Out:
# Mission
# Apollo11     21.55424
# Apollo12     34.34238
# Apollo14     41.83363
# Apollo15     75.39910
# Apollo16     92.46262
# Apollo17    109.44402
# Name: Weight (kg), dtype: float64

# %%
missions = pd.merge(missions, sample_total_weight, on='Mission')
missions
# Out:
#     Mission  Weight (kg)
# 0  Apollo11     21.55424
# 1  Apollo12     34.34238
# 2  Apollo14     41.83363
# 3  Apollo15     75.39910
# 4  Apollo16     92.46262
# 5  Apollo17    109.44402

# %%
missions.rename(columns={'Weight (kg)':'Sample Weight (kg)'}, inplace=True)
missions
# Out:
#     Mission  Sample Weight (kg)
# 0  Apollo11            21.55424
# 1  Apollo12            34.34238
# 2  Apollo14            41.83363
# 3  Apollo15            75.39910
# 4  Apollo16            92.46262
# 5  Apollo17           109.44402

# %%
missions['diff (kg)'] = missions['Sample Weight (kg)'].diff()
missions['diff (kg)'].fillna(0, inplace=True)
missions
# Out:
#     Mission  Sample Weight (kg)  diff (kg)
# 0  Apollo11            21.55424    0.00000
# 1  Apollo12            34.34238   12.78814
# 2  Apollo14            41.83363    7.49125
# 3  Apollo15            75.39910   33.56547
# 4  Apollo16            92.46262   17.06352
# 5  Apollo17           109.44402   16.98140

# %%
missions['weight diff (LM)'] = ['Eagle (LM-5)', 'Intrepid (LM-6)', 'Antares (LM-8)', 'Falcon (LM-10)', 'Orion (LM-11)', 'Challenger (LM-12)']
missions['LM mass (kg)'] = [15103, 15235, 15264, 16430, 16445, 16456]
missions
# Out:
#     Mission  Sample Weight (kg)  diff (kg)    weight diff (LM)  LM mass (kg)
# 0  Apollo11            21.55424    0.00000        Eagle (LM-5)         15103
# 1  Apollo12            34.34238   12.78814     Intrepid (LM-6)         15235
# 2  Apollo14            41.83363    7.49125      Antares (LM-8)         15264
# 3  Apollo15            75.39910   33.56547      Falcon (LM-10)         16430
# 4  Apollo16            92.46262   17.06352       Orion (LM-11)         16445
# 5  Apollo17           109.44402   16.98140  Challenger (LM-12)         16456

# %%
missions['LM mass diff'] = missions['LM mass (kg)'].diff()
missions['LM mass diff'].fillna(0, inplace=True)
missions
# Out:
#     Mission  Sample Weight (kg)  diff (kg)    weight diff (LM)  LM mass (kg)  \
# 0  Apollo11            21.55424    0.00000        Eagle (LM-5)         15103
# 1  Apollo12            34.34238   12.78814     Intrepid (LM-6)         15235
# 2  Apollo14            41.83363    7.49125      Antares (LM-8)         15264
# 3  Apollo15            75.39910   33.56547      Falcon (LM-10)         16430
# 4  Apollo16            92.46262   17.06352       Orion (LM-11)         16445
# 5  Apollo17           109.44402   16.98140  Challenger (LM-12)         16456
#
#    LM mass diff
# 0           0.0
# 1         132.0
# 2          29.0
# 3        1166.0
# 4          15.0
# 5          11.0

# %%
missions['Command module (LM)'] = ['Columbi(a (CSM-107)', 'Yankee Clipper (CSM-108)', 'Kitty Hawk (CM-110)', 'Endeavor (CM-112)', 'Casper (CM-113)', 'America (CM-114)']
missions['CM mass (kg)'] = [5560, 5609, 5758, 5875, 5840, 5960]
missions['CM mass diff'] = missions['CM mass (kg)'].diff()
missions['CM mass diff'] = missions['CM mass diff'].fillna(value=0)
missions
# Out:
#     Mission  Sample Weight (kg)  diff (kg)    weight diff (LM)  LM mass (kg)  \
# 0  Apollo11            21.55424    0.00000        Eagle (LM-5)         15103
# 1  Apollo12            34.34238   12.78814     Intrepid (LM-6)         15235
# 2  Apollo14            41.83363    7.49125      Antares (LM-8)         15264
# 3  Apollo15            75.39910   33.56547      Falcon (LM-10)         16430
# 4  Apollo16            92.46262   17.06352       Orion (LM-11)         16445
# 5  Apollo17           109.44402   16.98140  Challenger (LM-12)         16456
#
#    LM mass diff       Command module (LM)  CM mass (kg)  CM mass diff
# 0           0.0       Columbi(a (CSM-107)          5560           0.0
# 1         132.0  Yankee Clipper (CSM-108)          5609          49.0
# 2          29.0       Kitty Hawk (CM-110)          5758         149.0
# 3        1166.0         Endeavor (CM-112)          5875         117.0
# 4          15.0           Casper (CM-113)          5840         -35.0
# ...

# %%
missions['Total weight (kg)'] = missions['LM mass (kg)'] + missions['CM mass (kg)']
missions['Total weight diff'] = missions['LM mass diff'] + missions['CM mass diff']
missions
# Out:
#     Mission  Sample Weight (kg)  diff (kg)    weight diff (LM)  LM mass (kg)  \
# 0  Apollo11            21.55424    0.00000        Eagle (LM-5)         15103
# 1  Apollo12            34.34238   12.78814     Intrepid (LM-6)         15235
# 2  Apollo14            41.83363    7.49125      Antares (LM-8)         15264
# 3  Apollo15            75.39910   33.56547      Falcon (LM-10)         16430
# 4  Apollo16            92.46262   17.06352       Orion (LM-11)         16445
# 5  Apollo17           109.44402   16.98140  Challenger (LM-12)         16456
#
#    LM mass diff       Command module (LM)  CM mass (kg)  CM mass diff  \
# 0           0.0       Columbi(a (CSM-107)          5560           0.0
# 1         132.0  Yankee Clipper (CSM-108)          5609          49.0
# 2          29.0       Kitty Hawk (CM-110)          5758         149.0
# 3        1166.0         Endeavor (CM-112)          5875         117.0
# 4          15.0           Casper (CM-113)          5840         -35.0
# ...

# %%
saturnPlayoad = 43500
missions['Crewed area : plyload'] = missions['Total weight (kg)'] / saturnPlayoad
missions['Sample : Crewed area'] = missions['Sample Weight (kg)'] / missions['Total weight (kg)']
missions['Sample : payload'] = missions['Sample Weight (kg)'] / saturnPlayoad
missions
# Out:
#     Mission  Sample Weight (kg)  diff (kg)    weight diff (LM)  LM mass (kg)  \
# 0  Apollo11            21.55424    0.00000        Eagle (LM-5)         15103
# 1  Apollo12            34.34238   12.78814     Intrepid (LM-6)         15235
# 2  Apollo14            41.83363    7.49125      Antares (LM-8)         15264
# 3  Apollo15            75.39910   33.56547      Falcon (LM-10)         16430
# 4  Apollo16            92.46262   17.06352       Orion (LM-11)         16445
# 5  Apollo17           109.44402   16.98140  Challenger (LM-12)         16456
#
#    LM mass diff       Command module (LM)  CM mass (kg)  CM mass diff  \
# 0           0.0       Columbi(a (CSM-107)          5560           0.0
# 1         132.0  Yankee Clipper (CSM-108)          5609          49.0
# 2          29.0       Kitty Hawk (CM-110)          5758         149.0
# 3        1166.0         Endeavor (CM-112)          5875         117.0
# 4          15.0           Casper (CM-113)          5840         -35.0
# ...

# %%
artemis_crewedArea = 26520
artemis_mission = pd.DataFrame({
    'Mission' : ['artemis1', 'artemis1b', 'artemis2'],
    'Total weight (kg)':[artemis_crewedArea, artemis_crewedArea,artemis_crewedArea],
    'Payload (kg)':[26988,37965,42955]
})
artemis_mission
# Out:
#      Mission  Total weight (kg)  Payload (kg)
# 0   artemis1              26520         26988
# 1  artemis1b              26520         37965
# 2   artemis2              26520         42955

# %%
crewedArea_payload_ratio = missions['Crewed area : plyload'].mean()
sample_crewedArea_ratio = missions['Sample : Crewed area'].mean()
sample_payload_ratio = missions['Sample : payload'].mean()
print(crewedArea_payload_ratio)
print(sample_crewedArea_ratio)
print(sample_payload_ratio)
# Out:
# 0.4963026819923371
# 0.002848764392685611
# 0.0014369195019157087

# %%
artemis_mission['Sample weight from total (kg)'] = artemis_mission['Total weight (kg)'] * sample_crewedArea_ratio
artemis_mission['Sample weight from payload (kg)'] = artemis_mission['Payload (kg)']  * sample_payload_ratio
artemis_mission
# Out:
#      Mission  Total weight (kg)  Payload (kg)  Sample weight from total (kg)  \
# 0   artemis1              26520         26988                      75.549232
# 1  artemis1b              26520         37965                      75.549232
# 2   artemis2              26520         42955                      75.549232
#
#    Sample weight from payload (kg)
# 0                        38.779584
# 1                        54.552649
# 2                        61.722877

# %%
artemis_mission['Estimated sample weight (kg)'] = (artemis_mission['Sample weight from payload (kg)'] + artemis_mission['Sample weight from total (kg)']) / 2
artemis_mission
# Out:
#      Mission  Total weight (kg)  Payload (kg)  Sample weight from total (kg)  \
# 0   artemis1              26520         26988                      75.549232
# 1  artemis1b              26520         37965                      75.549232
# 2   artemis2              26520         42955                      75.549232
#
#    Sample weight from payload (kg)  Estimated sample weight (kg)
# 0                        38.779584                     57.164408
# 1                        54.552649                     65.050940
# 2                        61.722877                     68.636054
